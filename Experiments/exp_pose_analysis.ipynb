# %%
from pathlib import Path
import re
import numpy as np
from typing import Dict, List, Tuple, Optional

# Root directory (relative to the current notebook)
ROOT = Path("./PoseErrors")
APE_DIR = ROOT / "APE"
RPE_DIR = ROOT / "RPE"
RPEr_DIR = ROOT / "RPEr"

# Short-Full code in the file name (one-to-one correspondence with the full name)
short_tags: List[str] = ["orb", "akz", "kaz", "sft", "bsk", "spp"]
full_names: List[str] = ["ORB", "AKZ", "KAZ", "SFT", "BSK", "SPP"]

# Decimal places: display precision of mean±std in LaTeX
PREC = 3

# Unit scaling: 1=meter, 100=centimeter, 1000=millimeters
SCALE = 1000.0
UNIT_LABEL = "mm"   # "mm" or "m" etc.

# Whether to only accept combinations consisting entirely of short_tags; if False, unknown tags will be displayed in uppercase fallback
STRICT_TAGS = True

# Generate mapping
TAG2NAME: Dict[str, str] = dict(zip(short_tags, full_names))

def parse_20_runs_metrics(txt_path: Path) -> Dict[str, List[float]]:
    got = {"mean": [], "median": [], "rmse": []}
    if not txt_path.is_file():
        return got

    key_pat = re.compile(r"^\s*(mean|median|rmse)\s+([+-]?\d+(?:\.\d+)?(?:[eE][+-]?\d+)?)\s*$", re.I)

    with txt_path.open("r", encoding="utf-8", errors="ignore") as f:
        for line in f:
            m = key_pat.match(line)
            if m:
                k = m.group(1).lower()
                v = float(m.group(2))
                got[k].append(v)

    return got


def aggregate_mean_std(vals: List[float]) -> Tuple[Optional[float], Optional[float], int]:
    n = len(vals)
    if n == 0:
        return (None, None, 0)
    arr = np.asarray(vals, float)
    m = float(np.mean(arr))
    sd = float(np.std(arr, ddof=1)) if n > 1 else 0.0
    return (m, sd, n)


def collect_dir(dir_path: Path, dataset_prefix: str, tag2name: Dict[str, str], strict: bool) -> Dict[str, dict]:
    rows = {}
    for p in sorted(dir_path.glob(f"{dataset_prefix}*.txt")):
        combo = p.stem[len(dataset_prefix):]  # e.g. "akz_kaz"
        tags = [t for t in combo.split("_") if t]

        if strict and any(t not in tag2name for t in tags):
            continue

        label_parts = [(tag2name.get(t, t.upper())) for t in tags]
        label = " + ".join(label_parts) if label_parts else combo.upper()

        got = parse_20_runs_metrics(p)
        m_mean, s_mean, n_mean = aggregate_mean_std(got["mean"])
        m_median, s_median, n_median = aggregate_mean_std(got["median"])
        m_rmse, s_rmse, n_rmse = aggregate_mean_std(got["rmse"])

        rows[combo] = {
            "label": label,
            "metrics": {
                "mean":   {"mean": m_mean,   "std": s_mean,   "n": n_mean},
                "median": {"mean": m_median, "std": s_median, "n": n_median},
                "rmse":   {"mean": m_rmse,   "std": s_rmse,   "n": n_rmse},
            },
            "tags": tags,
        }
    return rows


def merge_ape_rpe(ape_rows: Dict[str, dict], rpe_rows: Dict[str, dict]) -> List[dict]:
    all_keys = sorted(set(ape_rows.keys()) | set(rpe_rows.keys()))
    out = []
    for k in all_keys:
        label = (ape_rows.get(k) or rpe_rows.get(k))["label"]
        tags  = (ape_rows.get(k) or rpe_rows.get(k))["tags"]
        out.append({
            "key": k,
            "label": label,
            "tags": tags,
            "APE": ape_rows.get(k, {}).get("metrics") if k in ape_rows else None,
            "RPE": rpe_rows.get(k, {}).get("metrics") if k in rpe_rows else None,
        })
    out.sort(key=lambda r: (len(r["tags"]), r["label"]))
    return out

def fmt_cell(m: Optional[float], s: Optional[float], prec: int, bold: bool) -> str:
    if m is None or s is None:
        return "--"
    m *= SCALE
    s *= SCALE
    txt = f"{m:.{prec}f} $\\pm$ {s:.{prec}f}"
    return f"\\textbf{{{txt}}}" if bold else txt


def build_latex_table(rows: List[dict], prec: int = 5) -> str:
    col_vals = {
        "A_mean": [],
        "A_rmse": [],
        "R_mean": [],
        "R_rmse": [],
    }
    for i, r in enumerate(rows):
        A = r["APE"]; R = r["RPE"]
        if A:
            if A["mean"]["mean"] is not None: col_vals["A_mean"].append((i, A["mean"]["mean"]))
            if A["rmse"]["mean"] is not None: col_vals["A_rmse"].append((i, A["rmse"]["mean"]))
        if R:
            if R["mean"]["mean"] is not None: col_vals["R_mean"].append((i, R["mean"]["mean"]))
            if R["rmse"]["mean"] is not None: col_vals["R_rmse"].append((i, R["rmse"]["mean"]))

    col_argmin = {k: (min(v, key=lambda t: t[1])[0] if v else None) for k, v in col_vals.items()}

    header = fr"""\begin{{table}}[htbp]
\centering
\caption{{Comparison of different inpainting regularizations under US and LA}}
\vspace{{0.2cm}}
\label{{tab:ape_rpe}}
\begin{{tabular}}{{lcccc}}
\toprule
\textbf{{Feature Extractor(s)}} &
\multicolumn{{2}}{{c}}{{\textbf{{Average Pose Error ({UNIT_LABEL})}}}} &
\multicolumn{{2}}{{c}}{{\textbf{{Relative Pose Error ({UNIT_LABEL}/f)}}}}  \\
\cmidrule(lr){{2-3}} \cmidrule(lr){{4-5}}
& Mean $\downarrow$ &  RMSE $\downarrow$ & Mean $\downarrow$  & RMSE $\downarrow$ \\
\midrule
"""
    body_lines = []
    for i, r in enumerate(rows):
        A = r["APE"]; R = r["RPE"]
        A_mean = fmt_cell(A["mean"]["mean"], A["mean"]["std"], prec, bold=(col_argmin["A_mean"] == i)) if A else "--"
        A_rmse = fmt_cell(A["rmse"]["mean"], A["rmse"]["std"], prec, bold=(col_argmin["A_rmse"] == i)) if A else "--"
        R_mean = fmt_cell(R["mean"]["mean"], R["mean"]["std"], prec, bold=(col_argmin["R_mean"] == i)) if R else "--"
        R_rmse = fmt_cell(R["rmse"]["mean"], R["rmse"]["std"], prec, bold=(col_argmin["R_rmse"] == i)) if R else "--"

        line = f"{r['label']}\n& {A_mean} & {A_rmse} & {R_mean} & {R_rmse} \\\\"
        body_lines.append(line)

    footer = r"""
\bottomrule
\end{tabular}
\end{table}
""".strip("\n")

    return header + "\n".join(body_lines) + "\n" + footer

# %%
# Dataset prefix (e.g. fr1 -> file name format is fr1_akz_kaz.txt)
DATASET = "fr1"
DATASET_PREFIX = f"{DATASET}_"

ape_rows = collect_dir(APE_DIR, DATASET_PREFIX, TAG2NAME, STRICT_TAGS)
rpe_rows = collect_dir(RPE_DIR, DATASET_PREFIX, TAG2NAME, STRICT_TAGS)
merged = merge_ape_rpe(ape_rows, rpe_rows)

latex_table = build_latex_table(merged, prec=PREC)
print(latex_table)
# Out:
# \begin{table}[htbp]
# \centering
# \caption{Comparison of different inpainting regularizations under US and LA}
# \vspace{0.2cm}
# \label{tab:ape_rpe}
# \begin{tabular}{lcccc}
# \toprule
# \textbf{Feature Extractor(s)} &
# \multicolumn{2}{c}{\textbf{Average Pose Error (mm)}} &
# \multicolumn{2}{c}{\textbf{Relative Pose Error (mm/f)}}  \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5}
# & Mean $\downarrow$ &  RMSE $\downarrow$ & Mean $\downarrow$  & RMSE $\downarrow$ \\
# \midrule
# AKZ
# & 8.497 $\pm$ 0.382 & 10.029 $\pm$ 0.471 & 4.998 $\pm$ 0.067 & 6.065 $\pm$ 0.147 \\
# BSK
# & 11.390 $\pm$ 1.972 & 13.475 $\pm$ 2.492 & 5.702 $\pm$ 0.168 & 7.202 $\pm$ 0.488 \\
# KAZ
# & 10.263 $\pm$ 1.343 & 12.176 $\pm$ 1.683 & 5.207 $\pm$ 0.142 & 6.612 $\pm$ 0.426 \\
# ORB
# & 19.033 $\pm$ 29.120 & 22.424 $\pm$ 31.245 & 6.457 $\pm$ 2.420 & 9.535 $\pm$ 4.810 \\
# SFT
# & 8.719 $\pm$ 0.283 & 10.393 $\pm$ 0.353 & 5.266 $\pm$ 0.107 & 6.517 $\pm$ 0.209 \\
# SPP
# & 22.241 $\pm$ 12.949 & 26.121 $\pm$ 15.415 & 5.843 $\pm$ 0.694 & 8.728 $\pm$ 2.469 \\
# AKZ + BSK
# & 27.880 $\pm$ 40.638 & 36.730 $\pm$ 51.467 & 5.803 $\pm$ 1.602 & 12.950 $\pm$ 13.259 \\
# AKZ + KAZ
# & 8.306 $\pm$ 0.298 & 9.780 $\pm$ 0.375 & 4.967 $\pm$ 0.063 & 6.017 $\pm$ 0.122 \\
# AKZ + SFT
# & 8.137 $\pm$ 0.160 & 9.585 $\pm$ 0.177 & 4.962 $\pm$ 0.061 & 6.044 $\pm$ 0.096 \\
# AKZ + SPP
# & 7.664 $\pm$ 0.179 & 8.972 $\pm$ 0.205 & 4.762 $\pm$ 0.034 & 5.776 $\pm$ 0.062 \\
# BSK + KAZ
# & 8.550 $\pm$ 0.277 & 10.076 $\pm$ 0.306 & 4.998 $\pm$ 0.070 & 6.057 $\pm$ 0.126 \\
# BSK + SFT
# & 8.269 $\pm$ 0.156 & 9.880 $\pm$ 0.206 & 5.004 $\pm$ 0.072 & 6.091 $\pm$ 0.133 \\
# BSK + SPP
# & \textbf{7.578 $\pm$ 0.199} & \textbf{8.948 $\pm$ 0.243} & 4.755 $\pm$ 0.036 & 5.738 $\pm$ 0.059 \\
# KAZ + SFT
# & 8.377 $\pm$ 0.187 & 9.962 $\pm$ 0.219 & 4.975 $\pm$ 0.055 & 6.053 $\pm$ 0.082 \\
# KAZ + SPP
# & 7.703 $\pm$ 0.141 & 9.082 $\pm$ 0.154 & 4.796 $\pm$ 0.052 & 5.815 $\pm$ 0.067 \\
# ORB + AKZ
# & 8.020 $\pm$ 0.136 & 9.443 $\pm$ 0.164 & 4.845 $\pm$ 0.047 & 5.847 $\pm$ 0.068 \\
# ORB + BSK
# & 8.023 $\pm$ 0.206 & 9.513 $\pm$ 0.252 & 4.927 $\pm$ 0.059 & 5.906 $\pm$ 0.090 \\
# ORB + KAZ
# & 8.155 $\pm$ 0.255 & 9.618 $\pm$ 0.279 & 4.858 $\pm$ 0.053 & 5.847 $\pm$ 0.089 \\
# ORB + SFT
# & 8.010 $\pm$ 0.162 & 9.526 $\pm$ 0.201 & 4.903 $\pm$ 0.041 & 5.962 $\pm$ 0.073 \\
# ORB + SPP
# & 7.630 $\pm$ 0.139 & 9.022 $\pm$ 0.158 & \textbf{4.700 $\pm$ 0.037} & \textbf{5.732 $\pm$ 0.064} \\
# SFT + SPP
# & 8.614 $\pm$ 2.108 & 11.549 $\pm$ 8.474 & 5.106 $\pm$ 0.464 & 7.129 $\pm$ 4.435 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
# Dataset prefix (e.g. fr1 -> file name format is fr1_akz_kaz.txt)
DATASET = "fr2"
DATASET_PREFIX = f"{DATASET}_"

ape_rows = collect_dir(APE_DIR, DATASET_PREFIX, TAG2NAME, STRICT_TAGS)
rpe_rows = collect_dir(RPE_DIR, DATASET_PREFIX, TAG2NAME, STRICT_TAGS)
merged = merge_ape_rpe(ape_rows, rpe_rows)

latex_table = build_latex_table(merged, prec=PREC)
print(latex_table)
# Out:
# \begin{table}[htbp]
# \centering
# \caption{Comparison of different inpainting regularizations under US and LA}
# \vspace{0.2cm}
# \label{tab:ape_rpe}
# \begin{tabular}{lcccc}
# \toprule
# \textbf{Feature Extractor(s)} &
# \multicolumn{2}{c}{\textbf{Average Pose Error (mm)}} &
# \multicolumn{2}{c}{\textbf{Relative Pose Error (mm/f)}}  \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5}
# & Mean $\downarrow$ &  RMSE $\downarrow$ & Mean $\downarrow$  & RMSE $\downarrow$ \\
# \midrule
# AKZ
# & 15.397 $\pm$ 8.616 & 19.202 $\pm$ 10.615 & 2.449 $\pm$ 0.293 & 5.032 $\pm$ 2.030 \\
# BSK
# & 15.824 $\pm$ 9.352 & 19.671 $\pm$ 10.930 & 2.719 $\pm$ 0.313 & 5.651 $\pm$ 2.186 \\
# KAZ
# & 21.720 $\pm$ 14.351 & 27.425 $\pm$ 17.914 & 2.223 $\pm$ 0.283 & 5.161 $\pm$ 2.373 \\
# ORB
# & 16.162 $\pm$ 11.069 & 20.763 $\pm$ 14.305 & 2.702 $\pm$ 0.506 & 5.622 $\pm$ 2.793 \\
# SFT
# & 12.641 $\pm$ 8.295 & 16.572 $\pm$ 10.647 & 2.373 $\pm$ 0.326 & 4.409 $\pm$ 1.875 \\
# SPP
# & 33.487 $\pm$ 10.415 & 41.583 $\pm$ 12.814 & 2.526 $\pm$ 0.288 & 7.683 $\pm$ 2.567 \\
# AKZ + BSK
# & 25.076 $\pm$ 54.584 & 40.480 $\pm$ 69.188 & 2.245 $\pm$ 1.039 & 12.407 $\pm$ 19.383 \\
# AKZ + KAZ
# & 12.457 $\pm$ 3.780 & 15.175 $\pm$ 4.584 & 1.794 $\pm$ 0.093 & 3.350 $\pm$ 0.744 \\
# AKZ + SFT
# & 7.820 $\pm$ 2.812 & 9.917 $\pm$ 3.630 & 1.796 $\pm$ 0.105 & 3.078 $\pm$ 0.746 \\
# AKZ + SPP
# & 3.430 $\pm$ 0.632 & 4.109 $\pm$ 0.861 & \textbf{1.582 $\pm$ 0.031} & 1.956 $\pm$ 0.152 \\
# BSK + KAZ
# & 12.925 $\pm$ 5.108 & 15.744 $\pm$ 6.385 & 1.889 $\pm$ 0.128 & 3.591 $\pm$ 0.997 \\
# BSK + SFT
# & 8.906 $\pm$ 2.558 & 11.013 $\pm$ 3.220 & 1.946 $\pm$ 0.139 & 3.479 $\pm$ 0.821 \\
# BSK + SPP
# & 2.724 $\pm$ 0.286 & 3.164 $\pm$ 0.335 & 1.628 $\pm$ 0.016 & 1.926 $\pm$ 0.044 \\
# KAZ + SFT
# & 11.084 $\pm$ 2.638 & 14.393 $\pm$ 3.619 & 1.820 $\pm$ 0.137 & 3.606 $\pm$ 0.952 \\
# KAZ + SPP
# & 4.258 $\pm$ 1.040 & 5.336 $\pm$ 1.473 & 1.605 $\pm$ 0.039 & 2.101 $\pm$ 0.265 \\
# ORB + AKZ
# & 3.716 $\pm$ 1.111 & 4.721 $\pm$ 1.651 & 1.692 $\pm$ 0.046 & 2.154 $\pm$ 0.278 \\
# ORB + BSK
# & 3.199 $\pm$ 0.800 & 3.764 $\pm$ 1.017 & 1.813 $\pm$ 0.059 & 2.182 $\pm$ 0.180 \\
# ORB + KAZ
# & 7.673 $\pm$ 1.832 & 10.012 $\pm$ 2.350 & 1.760 $\pm$ 0.070 & 2.736 $\pm$ 0.397 \\
# ORB + SFT
# & 4.410 $\pm$ 1.290 & 5.572 $\pm$ 1.720 & 1.741 $\pm$ 0.068 & 2.401 $\pm$ 0.347 \\
# ORB + SPP
# & \textbf{2.607 $\pm$ 0.385} & \textbf{3.099 $\pm$ 0.658} & 1.612 $\pm$ 0.020 & \textbf{1.904 $\pm$ 0.077} \\
# SFT + SPP
# & 9.011 $\pm$ 5.231 & 13.427 $\pm$ 16.026 & 1.907 $\pm$ 0.336 & 4.336 $\pm$ 6.147 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
# Unit scaling: 1=meter, 100=centimeter, 1000=millimeters
SCALE = 100.0
UNIT_LABEL = "cm"   # "mm" or "m" etc.

# Dataset prefix (e.g. fr1 -> file name format is fr1_akz_kaz.txt)
DATASET = "fr3"
DATASET_PREFIX = f"{DATASET}_"

ape_rows = collect_dir(APE_DIR, DATASET_PREFIX, TAG2NAME, STRICT_TAGS)
rpe_rows = collect_dir(RPE_DIR, DATASET_PREFIX, TAG2NAME, STRICT_TAGS)
merged = merge_ape_rpe(ape_rows, rpe_rows)

latex_table = build_latex_table(merged, prec=PREC)
print(latex_table)
# Out:
# \begin{table}[htbp]
# \centering
# \caption{Comparison of different inpainting regularizations under US and LA}
# \vspace{0.2cm}
# \label{tab:ape_rpe}
# \begin{tabular}{lcccc}
# \toprule
# \textbf{Feature Extractor(s)} &
# \multicolumn{2}{c}{\textbf{Average Pose Error (cm)}} &
# \multicolumn{2}{c}{\textbf{Relative Pose Error (cm/f)}}  \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5}
# & Mean $\downarrow$ &  RMSE $\downarrow$ & Mean $\downarrow$  & RMSE $\downarrow$ \\
# \midrule
# AKZ
# & 10.103 $\pm$ 16.763 & 11.704 $\pm$ 19.743 & 3.387 $\pm$ 2.316 & 4.776 $\pm$ 4.165 \\
# KAZ
# & 37.618 $\pm$ 22.656 & 43.058 $\pm$ 25.450 & 2.983 $\pm$ 0.760 & 6.018 $\pm$ 2.638 \\
# AKZ + BSK
# & 42.866 $\pm$ 23.073 & 47.927 $\pm$ 25.414 & 3.663 $\pm$ 0.997 & 6.315 $\pm$ 3.152 \\
# AKZ + KAZ
# & 21.433 $\pm$ 23.693 & 25.508 $\pm$ 27.314 & 2.742 $\pm$ 0.470 & 5.367 $\pm$ 3.234 \\
# AKZ + SFT
# & 25.950 $\pm$ 26.961 & 30.114 $\pm$ 29.092 & 3.588 $\pm$ 1.383 & 5.923 $\pm$ 2.642 \\
# AKZ + SPP
# & 1.990 $\pm$ 0.198 & 2.427 $\pm$ 0.465 & 2.459 $\pm$ 0.055 & 2.895 $\pm$ 0.185 \\
# BSK + KAZ
# & 41.419 $\pm$ 23.715 & 48.356 $\pm$ 27.170 & 2.577 $\pm$ 0.465 & 4.718 $\pm$ 1.421 \\
# BSK + SFT
# & 59.830 $\pm$ 8.034 & 67.085 $\pm$ 9.431 & 4.675 $\pm$ 1.454 & 12.344 $\pm$ 6.131 \\
# BSK + SPP
# & \textbf{1.850 $\pm$ 0.100} & \textbf{2.131 $\pm$ 0.122} & \textbf{1.945 $\pm$ 0.133} & \textbf{2.194 $\pm$ 0.169} \\
# KAZ + SFT
# & 49.461 $\pm$ 17.493 & 57.560 $\pm$ 20.099 & 2.622 $\pm$ 0.240 & 5.071 $\pm$ 1.208 \\
# KAZ + SPP
# & 41.333 $\pm$ 26.374 & 46.376 $\pm$ 28.814 & 3.828 $\pm$ 1.352 & 8.858 $\pm$ 3.730 \\
# ORB + AKZ
# & 20.903 $\pm$ 25.691 & 24.099 $\pm$ 29.040 & 3.971 $\pm$ 2.131 & 5.672 $\pm$ 3.566 \\
# ORB + KAZ
# & 24.538 $\pm$ 22.450 & 29.580 $\pm$ 26.864 & 3.077 $\pm$ 1.083 & 6.073 $\pm$ 3.647 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
from pathlib import Path

def _get_metrics(rows: Dict[str, dict], key: str) -> Optional[dict]:
    """小工具：安全地取 rows[key]['metrics'] 或 None。"""
    if key in rows and "metrics" in rows[key]:
        return rows[key]["metrics"]
    return None

def merge_ape_rpet_rper(ape_rows: Dict[str, dict],
                        rpet_rows: Dict[str, dict],
                        rper_rows: Dict[str, dict]) -> List[dict]:
    """合并 APE / RPEt / RPEr 三类结果为统一行结构。"""
    all_keys = sorted(set(ape_rows.keys()) | set(rpet_rows.keys()) | set(rper_rows.keys()))
    out = []
    for k in all_keys:
        src = ape_rows.get(k) or rpet_rows.get(k) or rper_rows.get(k)
        out.append({
            "key": k,
            "label": src["label"],
            "tags": src["tags"],
            "APE":  _get_metrics(ape_rows,  k),
            "RPEt": _get_metrics(rpet_rows, k),
            "RPEr": _get_metrics(rper_rows, k),
        })
    out.sort(key=lambda r: (len(r["tags"]), r["label"]))
    return out

def fmt_cell_scaled(m: Optional[float], s: Optional[float], scale: float, prec: int, bold: bool) -> str:
    """和原 fmt_cell 类似，但允许为每列传入独立缩放（如 mm、rad）。"""
    if m is None or s is None:
        return "--"
    m *= scale
    s *= scale
    txt = f"{m:.{prec}f} $\\pm$ {s:.{prec}f}"
    return f"\\textbf{{{txt}}}" if bold else txt

def build_latex_table_3(rows: List[dict],
                        dataset: str,
                        prec: int = 2,
                        prec_r: int = 3,
                        scale_mm: float = 1000.0) -> str:

    col_vals = {
        "A_mean": [], "A_rmse": [],
        "Rt_mean": [], "Rt_rmse": [],
        "Rr_mean": [], "Rr_rmse": [],
    }
    for i, r in enumerate(rows):
        A  = r["APE"]
        Rt = r["RPEt"]
        Rr = r["RPEr"]
        if A:
            if A["mean"]["mean"]  is not None: col_vals["A_mean"].append((i, A["mean"]["mean"]))
            if A["rmse"]["mean"]  is not None: col_vals["A_rmse"].append((i, A["rmse"]["mean"]))
        if Rt:
            if Rt["mean"]["mean"] is not None: col_vals["Rt_mean"].append((i, Rt["mean"]["mean"]))
            if Rt["rmse"]["mean"] is not None: col_vals["Rt_rmse"].append((i, Rt["rmse"]["mean"]))
        if Rr:
            if Rr["mean"]["mean"] is not None: col_vals["Rr_mean"].append((i, Rr["mean"]["mean"]))
            if Rr["rmse"]["mean"] is not None: col_vals["Rr_rmse"].append((i, Rr["rmse"]["mean"]))

    argmin_idx = {k: (min(v, key=lambda t: t[1])[0] if v else None) for k, v in col_vals.items()}

    header = fr"""\begin{{table}}[hbp]
\centering
\caption{{APE/RPE(trans/rot) on {dataset} sequence of 20 runs for all feature combinations}}
\scriptsize
\label{{tab:{dataset}_ape_rpe}}\
\setlength{{\tabcolsep}}{{3pt}}
\begin{{tabular}}{{lcccccc}}
\toprule
\textbf{{Extractor(s)}}
& \multicolumn{{2}}{{c}}{{\textbf{{APE ({UNIT_LABEL})}}}}
& \multicolumn{{2}}{{c}}{{\textbf{{RPEt ({UNIT_LABEL}/f)}}}}
& \multicolumn{{2}}{{c}}{{\textbf{{RPEr (deg/f)}}}} \\
\cmidrule(lr){{2-3}} \cmidrule(lr){{4-5}} \cmidrule(lr){{6-7}}
& Mean $\downarrow$ & RMSE $\downarrow$
& Mean $\downarrow$ & RMSE $\downarrow$
& Mean $\downarrow$ & RMSE $\downarrow$ \\
\midrule
"""
    body_lines = []
    for i, r in enumerate(rows):
        A  = r["APE"];  Rt = r["RPEt"];  Rr = r["RPEr"]

        A_mean  = fmt_cell_scaled(A["mean"]["mean"],  A["mean"]["std"],  scale_mm, prec, bold=(argmin_idx["A_mean"]  == i)) if A  else "--"
        A_rmse  = fmt_cell_scaled(A["rmse"]["mean"],  A["rmse"]["std"],  scale_mm, prec, bold=(argmin_idx["A_rmse"]  == i)) if A  else "--"
        Rt_mean = fmt_cell_scaled(Rt["mean"]["mean"], Rt["mean"]["std"], scale_mm, prec, bold=(argmin_idx["Rt_mean"] == i)) if Rt else "--"
        Rt_rmse = fmt_cell_scaled(Rt["rmse"]["mean"], Rt["rmse"]["std"], scale_mm, prec, bold=(argmin_idx["Rt_rmse"] == i)) if Rt else "--"
        Rr_mean = fmt_cell_scaled(Rr["mean"]["mean"], Rr["mean"]["std"], 1.0,     prec_r, bold=(argmin_idx["Rr_mean"] == i)) if Rr else "--"
        Rr_rmse = fmt_cell_scaled(Rr["rmse"]["mean"], Rr["rmse"]["std"], 1.0,     prec_r, bold=(argmin_idx["Rr_rmse"] == i)) if Rr else "--"

        line = f"{r['label']} & {A_mean} & {A_rmse} & {Rt_mean} & {Rt_rmse} & {Rr_mean} & {Rr_rmse} \\\\"
        body_lines.append(line)

    footer = r"""
\bottomrule
\end{tabular}
\end{table}
""".strip("\n")

    return header + "\n".join(body_lines) + "\n" + footer

# def build_latex_table_3(rows: List[dict],
#                         dataset: str,
#                         prec: int = 2,
#                         prec_r: int = 3,
#                         scale_mm: float = 1000.0,
#                         rper_in_degrees: bool = True) -> str:
#     """
#     Build a 3-block table using **Median** and **RMSE**:
#       - APE (mm)
#       - RPEt (mm/f)
#       - RPEr (deg/f by default; set rper_in_degrees=False to keep rad/f)
#
#     Boldfaces the minimum value in each column.
#     """
#     # Rotation unit / scaling
#     scale_r = (180.0 / np.pi) if rper_in_degrees else 1.0
#     rper_unit_label = "deg/f" if rper_in_degrees else "rad/f"
#
#     # Gather indices for bold (argmin per column)
#     col_vals = {
#         "A_med": [],  "A_rmse": [],
#         "Rt_med": [], "Rt_rmse": [],
#         "Rr_med": [], "Rr_rmse": [],
#     }
#     for i, r in enumerate(rows):
#         A  = r.get("APE")
#         Rt = r.get("RPEt")
#         Rr = r.get("RPEr")
#         if A:
#             if A["median"]["mean"] is not None: col_vals["A_med"].append((i, A["median"]["mean"]))
#             if A["rmse"]["mean"]   is not None: col_vals["A_rmse"].append((i, A["rmse"]["mean"]))
#         if Rt:
#             if Rt["median"]["mean"] is not None: col_vals["Rt_med"].append((i, Rt["median"]["mean"]))
#             if Rt["rmse"]["mean"]   is not None: col_vals["Rt_rmse"].append((i, Rt["rmse"]["mean"]))
#         if Rr:
#             if Rr["median"]["mean"] is not None: col_vals["Rr_med"].append((i, Rr["median"]["mean"]))
#             if Rr["rmse"]["mean"]   is not None: col_vals["Rr_rmse"].append((i, Rr["rmse"]["mean"]))
#
#     argmin_idx = {k: (min(v, key=lambda t: t[1])[0] if v else None) for k, v in col_vals.items()}
#
#     header = fr"""\begin{{table}}[hbp]
# \centering
# \caption{{APE/RPE(trans/rot) on {dataset} sequence of 20 runs for all feature combinations}}
# \footnotesize
# \label{{tab:{dataset}_ape_rpe}}\
# \setlength{{\tabcolsep}}{{3pt}}
# \begin{{tabular}}{{lcccccc}}
# \toprule
# \textbf{{Extractor(s)}}
# & \multicolumn{{2}}{{c}}{{\textbf{{APE ({UNIT_LABEL})}}}}
# & \multicolumn{{2}}{{c}}{{\textbf{{RPEt ({UNIT_LABEL}/f)}}}}
# & \multicolumn{{2}}{{c}}{{\textbf{{RPEr ({rper_unit_label})}}}} \\
# \cmidrule(lr){{2-3}} \cmidrule(lr){{4-5}} \cmidrule(lr){{6-7}}
# & Median $\downarrow$ & RMSE $\downarrow$
# & Median $\downarrow$ & RMSE $\downarrow$
# & Median $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# """
#
#     body_lines = []
#     for i, r in enumerate(rows):
#         A  = r.get("APE")
#         Rt = r.get("RPEt")
#         Rr = r.get("RPEr")
#
#         A_med  = fmt_cell_scaled(A["median"]["mean"], A["median"]["std"], scale_mm, prec,  bold=(argmin_idx["A_med"]  == i)) if A else "--"
#         A_rmse = fmt_cell_scaled(A["rmse"]["mean"],   A["rmse"]["std"],   scale_mm, prec,  bold=(argmin_idx["A_rmse"] == i)) if A else "--"
#
#         Rt_med  = fmt_cell_scaled(Rt["median"]["mean"], Rt["median"]["std"], scale_mm, prec,  bold=(argmin_idx["Rt_med"]  == i)) if Rt else "--"
#         Rt_rmse = fmt_cell_scaled(Rt["rmse"]["mean"],   Rt["rmse"]["std"],   scale_mm, prec,  bold=(argmin_idx["Rt_rmse"] == i)) if Rt else "--"
#
#         Rr_med  = fmt_cell_scaled(Rr["median"]["mean"], Rr["median"]["std"], scale_r,  prec_r, bold=(argmin_idx["Rr_med"]  == i)) if Rr else "--"
#         Rr_rmse = fmt_cell_scaled(Rr["rmse"]["mean"],   Rr["rmse"]["std"],   scale_r,  prec_r, bold=(argmin_idx["Rr_rmse"] == i)) if Rr else "--"
#
#         line = f"{r['label']} & {A_med} & {A_rmse} & {Rt_med} & {Rt_rmse} & {Rr_med} & {Rr_rmse} \\\\"
#         body_lines.append(line)
#
#     footer = r"""
# \bottomrule
# \end{tabular}
# \end{table}
# """.strip("\n")
#
#     return header + "\n".join(body_lines) + "\n" + footer


def make_ape_rpe_rper_table(dataset: str,
                            dataset_prefix: Optional[str] = None,
                            strict: bool = STRICT_TAGS,
                            prec: int = PREC,
                            prec_r: int = 3,) -> str:

    dp = dataset_prefix if dataset_prefix is not None else f"{dataset}_"

    # 目录均复用 collect_dir；RPEr_DIR 如果是 str，这里转为 Path 使用即可
    ape_rows  = collect_dir(APE_DIR,              dp, TAG2NAME, strict)
    rpet_rows = collect_dir(RPE_DIR,              dp, TAG2NAME, strict)
    rper_rows = collect_dir(Path(RPEr_DIR),       dp, TAG2NAME, strict)

    rows = merge_ape_rpet_rper(ape_rows, rpet_rows, rper_rows)
    # APE/RPEt 用 mm（SCALE=1000），RPEr 用 rad（scale=1）
    return build_latex_table_3(rows, dataset=dataset, prec=prec, scale_mm=SCALE, prec_r=prec_r)

# %%
SCALE = 1000.0
UNIT_LABEL = "mm"

latex = make_ape_rpe_rper_table("fr1",prec=3)
print(latex)

with open("./ResultFigs/ape_rpe_table_fr1.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on fr1 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:fr1_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (mm)}}
# & \multicolumn{2}{c}{\textbf{RPEt (mm/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 8.497 $\pm$ 0.382 & 10.029 $\pm$ 0.471 & 4.998 $\pm$ 0.067 & 6.065 $\pm$ 0.147 & 0.336 $\pm$ 0.003 & 0.395 $\pm$ 0.005 \\
# BSK & 11.390 $\pm$ 1.972 & 13.475 $\pm$ 2.492 & 5.702 $\pm$ 0.168 & 7.202 $\pm$ 0.488 & 0.356 $\pm$ 0.005 & 0.419 $\pm$ 0.007 \\
# KAZ & 10.263 $\pm$ 1.343 & 12.176 $\pm$ 1.683 & 5.207 $\pm$ 0.142 & 6.612 $\pm$ 0.426 & 0.337 $\pm$ 0.002 & 0.398 $\pm$ 0.004 \\
# ORB & 19.033 $\pm$ 29.120 & 22.424 $\pm$ 31.245 & 6.457 $\pm$ 2.420 & 9.535 $\pm$ 4.810 & 0.367 $\pm$ 0.092 & 0.442 $\pm$ 0.103 \\
# SFT & 8.719 $\pm$ 0.283 & 10.393 $\pm$ 0.353 & 5.266 $\pm$ 0.107 & 6.517 $\pm$ 0.209 & 0.344 $\pm$ 0.005 & 0.409 $\pm$ 0.007 \\
# SPP & 22.241 $\pm$ 12.949 & 26.121 $\pm$ 15.415 & 5.843 $\pm$ 0.694 & 8.728 $\pm$ 2.469 & 0.330 $\pm$ 0.004 & 0.392 $\pm$ 0.007 \\
# AKZ + BSK & 27.880 $\pm$ 40.638 & 36.730 $\pm$ 51.467 & 5.803 $\pm$ 1.602 & 12.950 $\pm$ 13.259 & 0.402 $\pm$ 0.149 & 1.152 $\pm$ 1.666 \\
# AKZ + KAZ & 8.306 $\pm$ 0.298 & 9.780 $\pm$ 0.375 & 4.967 $\pm$ 0.063 & 6.017 $\pm$ 0.122 & 0.335 $\pm$ 0.002 & 0.394 $\pm$ 0.003 \\
# AKZ + SFT & 8.137 $\pm$ 0.160 & 9.585 $\pm$ 0.177 & 4.962 $\pm$ 0.061 & 6.044 $\pm$ 0.096 & 0.335 $\pm$ 0.003 & 0.395 $\pm$ 0.005 \\
# AKZ + SPP & 7.664 $\pm$ 0.179 & 8.972 $\pm$ 0.205 & 4.762 $\pm$ 0.034 & 5.776 $\pm$ 0.062 & 0.329 $\pm$ 0.002 & 0.388 $\pm$ 0.003 \\
# BSK + KAZ & 8.550 $\pm$ 0.277 & 10.076 $\pm$ 0.306 & 4.998 $\pm$ 0.070 & 6.057 $\pm$ 0.126 & 0.336 $\pm$ 0.002 & 0.395 $\pm$ 0.003 \\
# BSK + SFT & 8.269 $\pm$ 0.156 & 9.880 $\pm$ 0.206 & 5.004 $\pm$ 0.072 & 6.091 $\pm$ 0.133 & 0.337 $\pm$ 0.003 & 0.398 $\pm$ 0.004 \\
# BSK + SPP & \textbf{7.578 $\pm$ 0.199} & \textbf{8.948 $\pm$ 0.243} & 4.755 $\pm$ 0.036 & 5.738 $\pm$ 0.059 & 0.330 $\pm$ 0.002 & 0.389 $\pm$ 0.003 \\
# KAZ + SFT & 8.377 $\pm$ 0.187 & 9.962 $\pm$ 0.219 & 4.975 $\pm$ 0.055 & 6.053 $\pm$ 0.082 & 0.334 $\pm$ 0.002 & 0.394 $\pm$ 0.003 \\
# KAZ + SPP & 7.703 $\pm$ 0.141 & 9.082 $\pm$ 0.154 & 4.796 $\pm$ 0.052 & 5.815 $\pm$ 0.067 & 0.330 $\pm$ 0.002 & 0.389 $\pm$ 0.003 \\
# ORB + AKZ & 8.020 $\pm$ 0.136 & 9.443 $\pm$ 0.164 & 4.845 $\pm$ 0.047 & 5.847 $\pm$ 0.068 & 0.333 $\pm$ 0.001 & 0.392 $\pm$ 0.002 \\
# ORB + BSK & 8.023 $\pm$ 0.206 & 9.513 $\pm$ 0.252 & 4.927 $\pm$ 0.059 & 5.906 $\pm$ 0.090 & 0.336 $\pm$ 0.002 & 0.395 $\pm$ 0.003 \\
# ORB + KAZ & 8.155 $\pm$ 0.255 & 9.618 $\pm$ 0.279 & 4.858 $\pm$ 0.053 & 5.847 $\pm$ 0.089 & 0.332 $\pm$ 0.002 & 0.391 $\pm$ 0.003 \\
# ORB + SFT & 8.010 $\pm$ 0.162 & 9.526 $\pm$ 0.201 & 4.903 $\pm$ 0.041 & 5.962 $\pm$ 0.073 & 0.333 $\pm$ 0.002 & 0.394 $\pm$ 0.003 \\
# ORB + SPP & 7.630 $\pm$ 0.139 & 9.022 $\pm$ 0.158 & \textbf{4.700 $\pm$ 0.037} & \textbf{5.732 $\pm$ 0.064} & \textbf{0.326 $\pm$ 0.003} & \textbf{0.386 $\pm$ 0.003} \\
# SFT + SPP & 8.614 $\pm$ 2.108 & 11.549 $\pm$ 8.474 & 5.106 $\pm$ 0.464 & 7.129 $\pm$ 4.435 & 0.345 $\pm$ 0.029 & 0.465 $\pm$ 0.284 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 1000.0
UNIT_LABEL = "mm"

latex = make_ape_rpe_rper_table("fr2",prec=3)
print(latex)

with open("./ResultFigs/ape_rpe_table_fr2.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on fr2 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:fr2_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (mm)}}
# & \multicolumn{2}{c}{\textbf{RPEt (mm/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 15.397 $\pm$ 8.616 & 19.202 $\pm$ 10.615 & 2.449 $\pm$ 0.293 & 5.032 $\pm$ 2.030 & 0.190 $\pm$ 0.006 & 0.239 $\pm$ 0.016 \\
# BSK & 15.824 $\pm$ 9.352 & 19.671 $\pm$ 10.930 & 2.719 $\pm$ 0.313 & 5.651 $\pm$ 2.186 & 0.189 $\pm$ 0.002 & 0.229 $\pm$ 0.004 \\
# KAZ & 21.720 $\pm$ 14.351 & 27.425 $\pm$ 17.914 & 2.223 $\pm$ 0.283 & 5.161 $\pm$ 2.373 & 0.181 $\pm$ 0.002 & 0.225 $\pm$ 0.007 \\
# ORB & 16.162 $\pm$ 11.069 & 20.763 $\pm$ 14.305 & 2.702 $\pm$ 0.506 & 5.622 $\pm$ 2.793 & 0.183 $\pm$ 0.004 & 0.230 $\pm$ 0.031 \\
# SFT & 12.641 $\pm$ 8.295 & 16.572 $\pm$ 10.647 & 2.373 $\pm$ 0.326 & 4.409 $\pm$ 1.875 & 0.180 $\pm$ 0.003 & 0.220 $\pm$ 0.004 \\
# SPP & 33.487 $\pm$ 10.415 & 41.583 $\pm$ 12.814 & 2.526 $\pm$ 0.288 & 7.683 $\pm$ 2.567 & 0.175 $\pm$ 0.001 & 0.214 $\pm$ 0.001 \\
# AKZ + BSK & 25.076 $\pm$ 54.584 & 40.480 $\pm$ 69.188 & 2.245 $\pm$ 1.039 & 12.407 $\pm$ 19.383 & 0.223 $\pm$ 0.106 & 0.948 $\pm$ 1.592 \\
# AKZ + KAZ & 12.457 $\pm$ 3.780 & 15.175 $\pm$ 4.584 & 1.794 $\pm$ 0.093 & 3.350 $\pm$ 0.744 & 0.176 $\pm$ 0.001 & 0.217 $\pm$ 0.001 \\
# AKZ + SFT & 7.820 $\pm$ 2.812 & 9.917 $\pm$ 3.630 & 1.796 $\pm$ 0.105 & 3.078 $\pm$ 0.746 & 0.176 $\pm$ 0.001 & 0.215 $\pm$ 0.001 \\
# AKZ + SPP & 3.430 $\pm$ 0.632 & 4.109 $\pm$ 0.861 & \textbf{1.582 $\pm$ 0.031} & 1.956 $\pm$ 0.152 & 0.173 $\pm$ 0.000 & 0.212 $\pm$ 0.000 \\
# BSK + KAZ & 12.925 $\pm$ 5.108 & 15.744 $\pm$ 6.385 & 1.889 $\pm$ 0.128 & 3.591 $\pm$ 0.997 & 0.178 $\pm$ 0.001 & 0.218 $\pm$ 0.001 \\
# BSK + SFT & 8.906 $\pm$ 2.558 & 11.013 $\pm$ 3.220 & 1.946 $\pm$ 0.139 & 3.479 $\pm$ 0.821 & 0.176 $\pm$ 0.001 & 0.215 $\pm$ 0.001 \\
# BSK + SPP & 2.724 $\pm$ 0.286 & 3.164 $\pm$ 0.335 & 1.628 $\pm$ 0.016 & 1.926 $\pm$ 0.044 & 0.174 $\pm$ 0.000 & 0.213 $\pm$ 0.000 \\
# KAZ + SFT & 11.084 $\pm$ 2.638 & 14.393 $\pm$ 3.619 & 1.820 $\pm$ 0.137 & 3.606 $\pm$ 0.952 & 0.175 $\pm$ 0.001 & 0.215 $\pm$ 0.001 \\
# KAZ + SPP & 4.258 $\pm$ 1.040 & 5.336 $\pm$ 1.473 & 1.605 $\pm$ 0.039 & 2.101 $\pm$ 0.265 & 0.173 $\pm$ 0.000 & 0.213 $\pm$ 0.001 \\
# ORB + AKZ & 3.716 $\pm$ 1.111 & 4.721 $\pm$ 1.651 & 1.692 $\pm$ 0.046 & 2.154 $\pm$ 0.278 & 0.175 $\pm$ 0.000 & 0.214 $\pm$ 0.001 \\
# ORB + BSK & 3.199 $\pm$ 0.800 & 3.764 $\pm$ 1.017 & 1.813 $\pm$ 0.059 & 2.182 $\pm$ 0.180 & 0.177 $\pm$ 0.001 & 0.215 $\pm$ 0.001 \\
# ORB + KAZ & 7.673 $\pm$ 1.832 & 10.012 $\pm$ 2.350 & 1.760 $\pm$ 0.070 & 2.736 $\pm$ 0.397 & 0.176 $\pm$ 0.001 & 0.216 $\pm$ 0.001 \\
# ORB + SFT & 4.410 $\pm$ 1.290 & 5.572 $\pm$ 1.720 & 1.741 $\pm$ 0.068 & 2.401 $\pm$ 0.347 & 0.174 $\pm$ 0.000 & 0.214 $\pm$ 0.000 \\
# ORB + SPP & \textbf{2.607 $\pm$ 0.385} & \textbf{3.099 $\pm$ 0.658} & 1.612 $\pm$ 0.020 & \textbf{1.904 $\pm$ 0.077} & \textbf{0.173 $\pm$ 0.000} & \textbf{0.212 $\pm$ 0.001} \\
# SFT + SPP & 9.011 $\pm$ 5.231 & 13.427 $\pm$ 16.026 & 1.907 $\pm$ 0.336 & 4.336 $\pm$ 6.147 & 0.177 $\pm$ 0.009 & 0.265 $\pm$ 0.229 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 100.0
UNIT_LABEL = "cm"

latex = make_ape_rpe_rper_table("fr3",prec=3)
print(latex)

with open("./ResultFigs/ape_rpe_table_fr3.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on fr3 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:fr3_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (cm)}}
# & \multicolumn{2}{c}{\textbf{RPEt (cm/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 10.103 $\pm$ 16.763 & 11.704 $\pm$ 19.743 & 3.387 $\pm$ 2.316 & 4.776 $\pm$ 4.165 & 0.848 $\pm$ 0.242 & 1.096 $\pm$ 0.484 \\
# KAZ & 37.618 $\pm$ 22.656 & 43.058 $\pm$ 25.450 & 2.983 $\pm$ 0.760 & 6.018 $\pm$ 2.638 & 0.629 $\pm$ 0.106 & 0.837 $\pm$ 0.188 \\
# AKZ + BSK & 42.866 $\pm$ 23.073 & 47.927 $\pm$ 25.414 & 3.663 $\pm$ 0.997 & 6.315 $\pm$ 3.152 & 0.696 $\pm$ 0.086 & 0.988 $\pm$ 0.280 \\
# AKZ + KAZ & 21.433 $\pm$ 23.693 & 25.508 $\pm$ 27.314 & 2.742 $\pm$ 0.470 & 5.367 $\pm$ 3.234 & 0.679 $\pm$ 0.107 & 1.016 $\pm$ 0.549 \\
# AKZ + SFT & 25.950 $\pm$ 26.961 & 30.114 $\pm$ 29.092 & 3.588 $\pm$ 1.383 & 5.923 $\pm$ 2.642 & 0.787 $\pm$ 0.077 & 1.103 $\pm$ 0.193 \\
# AKZ + SPP & 1.990 $\pm$ 0.198 & 2.427 $\pm$ 0.465 & 2.459 $\pm$ 0.055 & 2.895 $\pm$ 0.185 & 0.741 $\pm$ 0.018 & 0.879 $\pm$ 0.060 \\
# BSK + KAZ & 41.419 $\pm$ 23.715 & 48.356 $\pm$ 27.170 & 2.577 $\pm$ 0.465 & 4.718 $\pm$ 1.421 & 0.551 $\pm$ 0.114 & 0.688 $\pm$ 0.148 \\
# BSK + SFT & 59.830 $\pm$ 8.034 & 67.085 $\pm$ 9.431 & 4.675 $\pm$ 1.454 & 12.344 $\pm$ 6.131 & 0.628 $\pm$ 0.063 & 0.745 $\pm$ 0.120 \\
# BSK + SPP & \textbf{1.850 $\pm$ 0.100} & \textbf{2.131 $\pm$ 0.122} & \textbf{1.945 $\pm$ 0.133} & \textbf{2.194 $\pm$ 0.169} & 0.573 $\pm$ 0.044 & \textbf{0.639 $\pm$ 0.042} \\
# KAZ + SFT & 49.461 $\pm$ 17.493 & 57.560 $\pm$ 20.099 & 2.622 $\pm$ 0.240 & 5.071 $\pm$ 1.208 & \textbf{0.536 $\pm$ 0.076} & 0.670 $\pm$ 0.094 \\
# KAZ + SPP & 41.333 $\pm$ 26.374 & 46.376 $\pm$ 28.814 & 3.828 $\pm$ 1.352 & 8.858 $\pm$ 3.730 & 0.648 $\pm$ 0.062 & 1.024 $\pm$ 0.251 \\
# ORB + AKZ & 20.903 $\pm$ 25.691 & 24.099 $\pm$ 29.040 & 3.971 $\pm$ 2.131 & 5.672 $\pm$ 3.566 & 0.821 $\pm$ 0.120 & 1.053 $\pm$ 0.226 \\
# ORB + KAZ & 24.538 $\pm$ 22.450 & 29.580 $\pm$ 26.864 & 3.077 $\pm$ 1.083 & 6.073 $\pm$ 3.647 & 0.671 $\pm$ 0.100 & 0.897 $\pm$ 0.189 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 1.0
UNIT_LABEL = "m"

latex = make_ape_rpe_rper_table("kt01",prec=3)
print(latex)

with open("./ResultFigs/ape_rpe_table_kt01.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on kt01 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:kt01_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (m)}}
# & \multicolumn{2}{c}{\textbf{RPEt (m/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 430.563 $\pm$ 36.842 & 488.212 $\pm$ 45.295 & 2.853 $\pm$ 0.260 & 3.324 $\pm$ 0.334 & 0.138 $\pm$ 0.075 & 0.302 $\pm$ 0.294 \\
# BSK & 278.084 $\pm$ 95.513 & 360.479 $\pm$ 94.143 & 6.075 $\pm$ 2.333 & 21.866 $\pm$ 15.813 & 0.578 $\pm$ 0.185 & 3.377 $\pm$ 1.985 \\
# KAZ & 456.685 $\pm$ 11.678 & 520.726 $\pm$ 11.394 & 3.097 $\pm$ 0.091 & 3.816 $\pm$ 0.647 & 0.222 $\pm$ 0.100 & 0.921 $\pm$ 1.195 \\
# ORB & 421.804 $\pm$ 103.461 & 478.489 $\pm$ 117.084 & 2.928 $\pm$ 0.676 & 3.527 $\pm$ 0.756 & 0.134 $\pm$ 0.088 & 0.248 $\pm$ 0.321 \\
# SFT & 107.495 $\pm$ 93.971 & 136.299 $\pm$ 104.174 & 1.694 $\pm$ 1.561 & 9.395 $\pm$ 19.759 & 0.132 $\pm$ 0.112 & 0.971 $\pm$ 1.857 \\
# SPP & 272.941 $\pm$ 142.788 & 318.836 $\pm$ 154.207 & 10.319 $\pm$ 24.841 & 27.190 $\pm$ 72.054 & 0.503 $\pm$ 1.567 & 1.848 $\pm$ 6.587 \\
# AKZ + BSK & 268.659 $\pm$ 202.057 & 308.044 $\pm$ 226.869 & 2.452 $\pm$ 1.363 & 6.907 $\pm$ 12.848 & 0.192 $\pm$ 0.101 & 0.805 $\pm$ 0.959 \\
# AKZ + KAZ & 414.902 $\pm$ 65.658 & 469.843 $\pm$ 78.123 & 2.765 $\pm$ 0.401 & 3.217 $\pm$ 0.532 & 0.094 $\pm$ 0.017 & 0.160 $\pm$ 0.102 \\
# AKZ + SFT & 183.157 $\pm$ 144.769 & 221.857 $\pm$ 167.866 & 3.137 $\pm$ 5.589 & 12.840 $\pm$ 34.470 & 0.210 $\pm$ 0.388 & 1.233 $\pm$ 3.483 \\
# AKZ + SPP & 98.415 $\pm$ 93.957 & 109.403 $\pm$ 105.903 & \textbf{0.770 $\pm$ 0.547} & \textbf{0.941 $\pm$ 0.610} & 0.068 $\pm$ 0.012 & 0.101 $\pm$ 0.029 \\
# BSK + KAZ & 470.338 $\pm$ 6.557 & 536.132 $\pm$ 6.381 & 3.084 $\pm$ 0.039 & 3.615 $\pm$ 0.055 & 0.181 $\pm$ 0.063 & 0.298 $\pm$ 0.130 \\
# BSK + SFT & 103.182 $\pm$ 99.305 & 116.204 $\pm$ 111.313 & 0.831 $\pm$ 0.623 & 0.974 $\pm$ 0.647 & \textbf{0.061 $\pm$ 0.020} & \textbf{0.087 $\pm$ 0.037} \\
# BSK + SPP & \textbf{70.626 $\pm$ 46.124} & \textbf{79.491 $\pm$ 51.707} & 0.869 $\pm$ 0.367 & 1.243 $\pm$ 0.519 & 0.081 $\pm$ 0.017 & 0.111 $\pm$ 0.029 \\
# KAZ + SFT & 299.695 $\pm$ 96.270 & 335.383 $\pm$ 109.433 & 1.998 $\pm$ 0.614 & 2.264 $\pm$ 0.712 & 0.089 $\pm$ 0.078 & 0.173 $\pm$ 0.304 \\
# KAZ + SPP & 145.297 $\pm$ 96.946 & 164.316 $\pm$ 108.485 & 1.197 $\pm$ 0.629 & 1.998 $\pm$ 3.166 & 0.067 $\pm$ 0.023 & 0.127 $\pm$ 0.190 \\
# ORB + AKZ & 306.894 $\pm$ 136.311 & 345.694 $\pm$ 154.666 & 2.139 $\pm$ 0.752 & 2.643 $\pm$ 1.252 & 0.092 $\pm$ 0.018 & 0.132 $\pm$ 0.035 \\
# ORB + BSK & 407.900 $\pm$ 74.882 & 462.247 $\pm$ 87.371 & 2.756 $\pm$ 0.433 & 3.192 $\pm$ 0.557 & 0.092 $\pm$ 0.008 & 0.127 $\pm$ 0.013 \\
# ORB + KAZ & 437.796 $\pm$ 37.373 & 496.339 $\pm$ 41.726 & 2.974 $\pm$ 0.180 & 3.575 $\pm$ 0.315 & 0.110 $\pm$ 0.024 & 0.174 $\pm$ 0.066 \\
# ORB + SFT & 138.941 $\pm$ 139.337 & 171.179 $\pm$ 164.333 & 3.073 $\pm$ 6.192 & 16.232 $\pm$ 43.946 & 0.187 $\pm$ 0.376 & 0.932 $\pm$ 2.452 \\
# ORB + SPP & 148.842 $\pm$ 112.823 & 166.830 $\pm$ 125.118 & 1.226 $\pm$ 0.685 & 1.461 $\pm$ 0.727 & 0.080 $\pm$ 0.016 & 0.113 $\pm$ 0.033 \\
# SFT + SPP & 102.699 $\pm$ 120.773 & 135.145 $\pm$ 146.484 & 2.428 $\pm$ 3.982 & 12.149 $\pm$ 22.533 & 0.205 $\pm$ 0.239 & 1.289 $\pm$ 1.687 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 1.0
UNIT_LABEL = "m"

latex = make_ape_rpe_rper_table("kt04",prec=3, prec_r=4)
print(latex)

with open("./ResultFigs/ape_rpe_table_kt04.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on kt04 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:kt04_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (m)}}
# & \multicolumn{2}{c}{\textbf{RPEt (m/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 0.475 $\pm$ 0.171 & 0.528 $\pm$ 0.188 & 0.021 $\pm$ 0.003 & 0.024 $\pm$ 0.003 & 0.0293 $\pm$ 0.0007 & 0.0344 $\pm$ 0.0007 \\
# BSK & 0.379 $\pm$ 0.247 & 0.435 $\pm$ 0.283 & 0.034 $\pm$ 0.005 & 0.048 $\pm$ 0.007 & 0.0378 $\pm$ 0.0021 & 0.0473 $\pm$ 0.0047 \\
# KAZ & 0.405 $\pm$ 0.173 & 0.460 $\pm$ 0.198 & 0.024 $\pm$ 0.002 & 0.029 $\pm$ 0.003 & 0.0375 $\pm$ 0.0014 & 0.0437 $\pm$ 0.0020 \\
# ORB & 0.348 $\pm$ 0.094 & 0.420 $\pm$ 0.108 & 0.022 $\pm$ 0.002 & 0.025 $\pm$ 0.002 & 0.0354 $\pm$ 0.0008 & 0.0416 $\pm$ 0.0009 \\
# SFT & 0.510 $\pm$ 0.079 & 0.582 $\pm$ 0.092 & 0.020 $\pm$ 0.002 & \textbf{0.022 $\pm$ 0.002} & \textbf{0.0242 $\pm$ 0.0003} & \textbf{0.0293 $\pm$ 0.0004} \\
# SPP & \textbf{0.234 $\pm$ 0.068} & \textbf{0.265 $\pm$ 0.082} & 0.022 $\pm$ 0.001 & 0.025 $\pm$ 0.001 & 0.0396 $\pm$ 0.0012 & 0.0449 $\pm$ 0.0014 \\
# AKZ + BSK & 1.962 $\pm$ 1.333 & 2.353 $\pm$ 1.605 & 0.094 $\pm$ 0.064 & 0.220 $\pm$ 0.338 & 0.0989 $\pm$ 0.1212 & 0.4668 $\pm$ 1.2719 \\
# AKZ + KAZ & 0.274 $\pm$ 0.155 & 0.308 $\pm$ 0.186 & 0.022 $\pm$ 0.002 & 0.025 $\pm$ 0.003 & 0.0348 $\pm$ 0.0010 & 0.0408 $\pm$ 0.0013 \\
# AKZ + SFT & 0.291 $\pm$ 0.124 & 0.325 $\pm$ 0.148 & \textbf{0.020 $\pm$ 0.002} & 0.023 $\pm$ 0.003 & 0.0301 $\pm$ 0.0014 & 0.0362 $\pm$ 0.0040 \\
# AKZ + SPP & 0.270 $\pm$ 0.093 & 0.308 $\pm$ 0.111 & 0.030 $\pm$ 0.005 & 0.037 $\pm$ 0.008 & 0.0432 $\pm$ 0.0048 & 0.0510 $\pm$ 0.0059 \\
# BSK + KAZ & 0.329 $\pm$ 0.145 & 0.373 $\pm$ 0.168 & 0.027 $\pm$ 0.003 & 0.033 $\pm$ 0.006 & 0.0390 $\pm$ 0.0021 & 0.0464 $\pm$ 0.0040 \\
# BSK + SFT & 0.296 $\pm$ 0.110 & 0.329 $\pm$ 0.126 & 0.021 $\pm$ 0.002 & 0.024 $\pm$ 0.003 & 0.0295 $\pm$ 0.0008 & 0.0345 $\pm$ 0.0009 \\
# BSK + SPP & 0.523 $\pm$ 0.250 & 0.598 $\pm$ 0.289 & 0.035 $\pm$ 0.005 & 0.041 $\pm$ 0.007 & 0.0447 $\pm$ 0.0034 & 0.0517 $\pm$ 0.0044 \\
# KAZ + SFT & 0.413 $\pm$ 0.160 & 0.479 $\pm$ 0.186 & 0.022 $\pm$ 0.003 & 0.025 $\pm$ 0.003 & 0.0299 $\pm$ 0.0006 & 0.0353 $\pm$ 0.0009 \\
# KAZ + SPP & 0.293 $\pm$ 0.122 & 0.333 $\pm$ 0.143 & 0.022 $\pm$ 0.002 & 0.026 $\pm$ 0.002 & 0.0363 $\pm$ 0.0009 & 0.0437 $\pm$ 0.0010 \\
# ORB + AKZ & 0.651 $\pm$ 0.273 & 0.766 $\pm$ 0.316 & 0.037 $\pm$ 0.006 & 0.044 $\pm$ 0.008 & 0.0422 $\pm$ 0.0032 & 0.0490 $\pm$ 0.0048 \\
# ORB + BSK & 0.624 $\pm$ 0.200 & 0.710 $\pm$ 0.228 & 0.032 $\pm$ 0.003 & 0.038 $\pm$ 0.005 & 0.0405 $\pm$ 0.0025 & 0.0479 $\pm$ 0.0036 \\
# ORB + KAZ & 0.320 $\pm$ 0.106 & 0.374 $\pm$ 0.126 & 0.025 $\pm$ 0.001 & 0.029 $\pm$ 0.002 & 0.0375 $\pm$ 0.0013 & 0.0433 $\pm$ 0.0015 \\
# ORB + SFT & 0.311 $\pm$ 0.124 & 0.350 $\pm$ 0.139 & 0.037 $\pm$ 0.008 & 0.061 $\pm$ 0.026 & 0.0441 $\pm$ 0.0061 & 0.0642 $\pm$ 0.0200 \\
# ORB + SPP & 0.837 $\pm$ 0.590 & 0.961 $\pm$ 0.656 & 0.080 $\pm$ 0.039 & 0.113 $\pm$ 0.053 & 0.0907 $\pm$ 0.0304 & 0.1273 $\pm$ 0.0432 \\
# SFT + SPP & 1.015 $\pm$ 1.155 & 2.063 $\pm$ 2.436 & 0.157 $\pm$ 0.199 & 1.263 $\pm$ 1.926 & 0.2018 $\pm$ 0.2809 & 1.6781 $\pm$ 2.7166 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 1.0
UNIT_LABEL = "m"

latex = make_ape_rpe_rper_table("kt07",prec=3, prec_r=4)
print(latex)

with open("./ResultFigs/ape_rpe_table_kt07.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on kt07 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:kt07_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (m)}}
# & \multicolumn{2}{c}{\textbf{RPEt (m/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 4.790 $\pm$ 0.767 & 5.029 $\pm$ 0.791 & 0.280 $\pm$ 0.026 & 0.638 $\pm$ 0.159 & 0.0584 $\pm$ 0.0393 & 0.3076 $\pm$ 0.7820 \\
# BSK & 14.588 $\pm$ 0.649 & 17.811 $\pm$ 0.807 & 0.203 $\pm$ 0.009 & 2.524 $\pm$ 0.115 & 0.0418 $\pm$ 0.0015 & 0.0700 $\pm$ 0.0123 \\
# KAZ & 3.086 $\pm$ 0.515 & 3.348 $\pm$ 0.495 & 0.403 $\pm$ 0.032 & 0.808 $\pm$ 0.227 & 0.0779 $\pm$ 0.0561 & 0.4811 $\pm$ 0.8718 \\
# ORB & 10.183 $\pm$ 5.141 & 12.256 $\pm$ 6.549 & \textbf{0.128 $\pm$ 0.018} & 0.193 $\pm$ 0.068 & 0.0389 $\pm$ 0.0073 & 0.0621 $\pm$ 0.0724 \\
# SFT & 4.273 $\pm$ 0.934 & 4.551 $\pm$ 0.937 & 0.297 $\pm$ 0.020 & 0.583 $\pm$ 0.041 & 0.0391 $\pm$ 0.0113 & 0.0889 $\pm$ 0.1427 \\
# SPP & 4.181 $\pm$ 1.107 & 4.448 $\pm$ 1.194 & 0.513 $\pm$ 0.041 & 0.844 $\pm$ 0.094 & 0.1265 $\pm$ 0.0975 & 0.5768 $\pm$ 0.6548 \\
# AKZ + BSK & 11.964 $\pm$ 11.105 & 13.909 $\pm$ 12.820 & 0.870 $\pm$ 1.623 & 2.564 $\pm$ 4.737 & 0.8585 $\pm$ 1.9875 & 4.1742 $\pm$ 8.0213 \\
# AKZ + KAZ & 6.296 $\pm$ 0.433 & 6.494 $\pm$ 0.450 & 0.421 $\pm$ 0.019 & 0.593 $\pm$ 0.028 & 0.0442 $\pm$ 0.0014 & 0.0631 $\pm$ 0.0061 \\
# AKZ + SFT & 11.126 $\pm$ 4.510 & 12.364 $\pm$ 5.311 & 0.332 $\pm$ 0.203 & 1.354 $\pm$ 0.776 & 0.0624 $\pm$ 0.0157 & 0.1579 $\pm$ 0.0785 \\
# AKZ + SPP & 5.836 $\pm$ 3.429 & 6.305 $\pm$ 3.867 & 0.593 $\pm$ 0.166 & 1.348 $\pm$ 0.478 & 0.0735 $\pm$ 0.0321 & 0.1749 $\pm$ 0.2954 \\
# BSK + KAZ & \textbf{2.803 $\pm$ 0.579} & \textbf{3.115 $\pm$ 0.664} & 0.351 $\pm$ 0.024 & 0.529 $\pm$ 0.045 & 0.0464 $\pm$ 0.0038 & 0.0755 $\pm$ 0.0320 \\
# BSK + SFT & 13.435 $\pm$ 2.250 & 16.446 $\pm$ 2.883 & 0.145 $\pm$ 0.113 & \textbf{0.188 $\pm$ 0.176} & 0.0428 $\pm$ 0.0079 & 0.0620 $\pm$ 0.0322 \\
# BSK + SPP & 4.857 $\pm$ 3.588 & 5.466 $\pm$ 4.536 & 0.556 $\pm$ 0.164 & 0.980 $\pm$ 0.309 & 0.0590 $\pm$ 0.0035 & 0.0807 $\pm$ 0.0122 \\
# KAZ + SFT & 3.871 $\pm$ 0.613 & 4.042 $\pm$ 0.632 & 0.420 $\pm$ 0.032 & 0.571 $\pm$ 0.065 & 0.0478 $\pm$ 0.0042 & 0.0852 $\pm$ 0.0212 \\
# KAZ + SPP & 3.360 $\pm$ 0.587 & 3.699 $\pm$ 0.601 & 0.586 $\pm$ 0.027 & 0.833 $\pm$ 0.043 & \textbf{0.0388 $\pm$ 0.0014} & \textbf{0.0525 $\pm$ 0.0040} \\
# ORB + AKZ & 9.385 $\pm$ 3.873 & 10.734 $\pm$ 5.130 & 0.331 $\pm$ 0.168 & 0.706 $\pm$ 0.590 & 0.0608 $\pm$ 0.0124 & 0.1291 $\pm$ 0.1103 \\
# ORB + BSK & 11.893 $\pm$ 4.777 & 14.309 $\pm$ 6.192 & 0.218 $\pm$ 0.143 & 0.318 $\pm$ 0.251 & 0.0480 $\pm$ 0.0051 & 0.0614 $\pm$ 0.0102 \\
# ORB + KAZ & 4.649 $\pm$ 0.525 & 4.841 $\pm$ 0.523 & 0.460 $\pm$ 0.029 & 0.684 $\pm$ 0.047 & 0.0463 $\pm$ 0.0014 & 0.0595 $\pm$ 0.0038 \\
# ORB + SFT & 12.679 $\pm$ 2.871 & 15.197 $\pm$ 3.827 & 0.198 $\pm$ 0.157 & 0.673 $\pm$ 0.828 & 0.0557 $\pm$ 0.0193 & 0.1022 $\pm$ 0.0660 \\
# ORB + SPP & 7.375 $\pm$ 4.725 & 8.076 $\pm$ 5.314 & 0.555 $\pm$ 0.240 & 1.251 $\pm$ 0.523 & 0.0766 $\pm$ 0.0221 & 0.1481 $\pm$ 0.1084 \\
# SFT + SPP & 15.104 $\pm$ 10.574 & 16.577 $\pm$ 11.372 & 0.333 $\pm$ 0.143 & 1.777 $\pm$ 1.337 & 0.1354 $\pm$ 0.1093 & 0.9412 $\pm$ 1.4678 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 100.0
UNIT_LABEL = "cm"

latex = make_ape_rpe_rper_table("mh01",prec=3, prec_r=4)
print(latex)

with open("./ResultFigs/ape_rpe_table_mh01.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on mh01 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:mh01_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (cm)}}
# & \multicolumn{2}{c}{\textbf{RPEt (cm/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 2.851 $\pm$ 0.179 & 3.386 $\pm$ 0.176 & 2.276 $\pm$ 0.003 & 2.801 $\pm$ 0.005 & 0.5895 $\pm$ 0.0002 & 0.8240 $\pm$ 0.0002 \\
# BSK & 2.958 $\pm$ 0.175 & 3.542 $\pm$ 0.148 & 2.299 $\pm$ 0.004 & 2.825 $\pm$ 0.014 & 0.5907 $\pm$ 0.0004 & 0.8246 $\pm$ 0.0006 \\
# KAZ & 2.965 $\pm$ 0.328 & 3.542 $\pm$ 0.281 & 2.281 $\pm$ 0.004 & 2.805 $\pm$ 0.006 & 0.5891 $\pm$ 0.0002 & 0.8235 $\pm$ 0.0002 \\
# ORB & 3.268 $\pm$ 0.297 & 3.914 $\pm$ 0.231 & 2.336 $\pm$ 0.011 & 2.867 $\pm$ 0.013 & 0.5931 $\pm$ 0.0008 & 0.8254 $\pm$ 0.0005 \\
# SFT & \textbf{2.633 $\pm$ 0.121} & \textbf{3.174 $\pm$ 0.127} & 2.277 $\pm$ 0.009 & 2.798 $\pm$ 0.004 & 0.5891 $\pm$ 0.0005 & 0.8237 $\pm$ 0.0002 \\
# SPP & 2.952 $\pm$ 0.099 & 3.578 $\pm$ 0.106 & 2.314 $\pm$ 0.004 & 2.848 $\pm$ 0.006 & 0.5899 $\pm$ 0.0002 & 0.8238 $\pm$ 0.0002 \\
# AKZ + BSK & 8.912 $\pm$ 10.055 & 12.234 $\pm$ 14.502 & 2.333 $\pm$ 0.428 & 4.166 $\pm$ 3.107 & 0.6518 $\pm$ 0.1328 & 1.6850 $\pm$ 1.6810 \\
# AKZ + KAZ & 2.742 $\pm$ 0.125 & 3.410 $\pm$ 0.136 & 2.268 $\pm$ 0.002 & 2.790 $\pm$ 0.002 & 0.5884 $\pm$ 0.0002 & 0.8232 $\pm$ 0.0001 \\
# AKZ + SFT & 2.656 $\pm$ 0.100 & 3.240 $\pm$ 0.109 & \textbf{2.268 $\pm$ 0.002} & \textbf{2.789 $\pm$ 0.002} & 0.5885 $\pm$ 0.0001 & 0.8233 $\pm$ 0.0001 \\
# AKZ + SPP & 2.819 $\pm$ 0.094 & 3.501 $\pm$ 0.097 & 2.270 $\pm$ 0.002 & 2.791 $\pm$ 0.002 & 0.5889 $\pm$ 0.0002 & 0.8233 $\pm$ 0.0001 \\
# BSK + KAZ & 2.927 $\pm$ 0.093 & 3.632 $\pm$ 0.098 & 2.271 $\pm$ 0.002 & 2.792 $\pm$ 0.002 & 0.5886 $\pm$ 0.0002 & 0.8232 $\pm$ 0.0002 \\
# BSK + SFT & 2.755 $\pm$ 0.091 & 3.439 $\pm$ 0.094 & 2.270 $\pm$ 0.002 & 2.791 $\pm$ 0.003 & 0.5885 $\pm$ 0.0003 & \textbf{0.8232 $\pm$ 0.0002} \\
# BSK + SPP & 2.882 $\pm$ 0.054 & 3.611 $\pm$ 0.051 & 2.280 $\pm$ 0.002 & 2.801 $\pm$ 0.002 & 0.5890 $\pm$ 0.0002 & 0.8233 $\pm$ 0.0001 \\
# KAZ + SFT & 2.641 $\pm$ 0.088 & 3.267 $\pm$ 0.097 & 2.269 $\pm$ 0.002 & 2.791 $\pm$ 0.002 & \textbf{0.5883 $\pm$ 0.0001} & 0.8232 $\pm$ 0.0001 \\
# KAZ + SPP & 2.768 $\pm$ 0.116 & 3.461 $\pm$ 0.138 & 2.272 $\pm$ 0.002 & 2.793 $\pm$ 0.002 & 0.5887 $\pm$ 0.0001 & 0.8233 $\pm$ 0.0002 \\
# ORB + AKZ & 3.142 $\pm$ 0.191 & 3.779 $\pm$ 0.168 & 2.277 $\pm$ 0.002 & 2.800 $\pm$ 0.003 & 0.5891 $\pm$ 0.0002 & 0.8236 $\pm$ 0.0002 \\
# ORB + BSK & 3.098 $\pm$ 0.162 & 3.727 $\pm$ 0.130 & 2.279 $\pm$ 0.003 & 2.803 $\pm$ 0.011 & 0.5895 $\pm$ 0.0007 & 0.8238 $\pm$ 0.0008 \\
# ORB + KAZ & 3.090 $\pm$ 0.207 & 3.785 $\pm$ 0.175 & 2.270 $\pm$ 0.002 & 2.792 $\pm$ 0.003 & 0.5886 $\pm$ 0.0001 & 0.8232 $\pm$ 0.0002 \\
# ORB + SFT & 3.074 $\pm$ 0.182 & 3.728 $\pm$ 0.157 & 2.273 $\pm$ 0.003 & 2.796 $\pm$ 0.003 & 0.5886 $\pm$ 0.0002 & 0.8233 $\pm$ 0.0001 \\
# ORB + SPP & 2.988 $\pm$ 0.078 & 3.710 $\pm$ 0.080 & 2.282 $\pm$ 0.002 & 2.804 $\pm$ 0.003 & 0.5893 $\pm$ 0.0002 & 0.8233 $\pm$ 0.0002 \\
# SFT + SPP & 4.424 $\pm$ 4.725 & 5.225 $\pm$ 5.368 & 2.280 $\pm$ 0.033 & 2.829 $\pm$ 0.127 & 0.5966 $\pm$ 0.0296 & 0.9882 $\pm$ 0.7330 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 100.0
UNIT_LABEL = "cm"

latex = make_ape_rpe_rper_table("mh03",prec=3, prec_r=4)
print(latex)

with open("./ResultFigs/ape_rpe_table_mh03.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on mh03 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:mh03_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (cm)}}
# & \multicolumn{2}{c}{\textbf{RPEt (cm/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 4.126 $\pm$ 0.444 & 5.049 $\pm$ 2.275 & 5.614 $\pm$ 0.048 & 7.581 $\pm$ 1.824 & 0.8837 $\pm$ 0.0107 & 1.2511 $\pm$ 0.2014 \\
# BSK & \textbf{0.224 $\pm$ 0.033} & \textbf{0.272 $\pm$ 0.055} & \textbf{1.295 $\pm$ 0.038} & \textbf{1.607 $\pm$ 0.017} & 0.9110 $\pm$ 0.0086 & \textbf{0.9508 $\pm$ 0.0124} \\
# KAZ & 3.927 $\pm$ 0.605 & 4.503 $\pm$ 0.672 & 5.575 $\pm$ 0.010 & 7.145 $\pm$ 0.009 & 0.8822 $\pm$ 0.0010 & 1.2074 $\pm$ 0.0016 \\
# ORB & 3.266 $\pm$ 0.206 & 3.749 $\pm$ 0.207 & 5.658 $\pm$ 0.013 & 7.221 $\pm$ 0.012 & 0.8817 $\pm$ 0.0010 & 1.2050 $\pm$ 0.0014 \\
# SFT & 3.458 $\pm$ 0.601 & 4.487 $\pm$ 2.097 & 5.471 $\pm$ 0.716 & 7.797 $\pm$ 2.298 & 0.9289 $\pm$ 0.1889 & 1.4530 $\pm$ 0.6231 \\
# SPP & 4.389 $\pm$ 3.617 & 5.071 $\pm$ 4.499 & 5.638 $\pm$ 0.042 & 7.198 $\pm$ 0.063 & 0.8801 $\pm$ 0.0009 & 1.2046 $\pm$ 0.0007 \\
# AKZ + BSK & 15.275 $\pm$ 10.478 & 25.965 $\pm$ 21.520 & 6.001 $\pm$ 0.545 & 13.550 $\pm$ 10.228 & 0.9178 $\pm$ 0.0506 & 1.7204 $\pm$ 0.8957 \\
# AKZ + KAZ & 3.389 $\pm$ 0.191 & 3.956 $\pm$ 0.181 & 5.634 $\pm$ 0.019 & 7.198 $\pm$ 0.056 & 0.8799 $\pm$ 0.0014 & 1.2065 $\pm$ 0.0042 \\
# AKZ + SFT & 3.331 $\pm$ 0.305 & 3.835 $\pm$ 0.362 & 5.609 $\pm$ 0.017 & 7.167 $\pm$ 0.022 & 0.8783 $\pm$ 0.0006 & 1.2034 $\pm$ 0.0015 \\
# AKZ + SPP & 2.993 $\pm$ 0.091 & 3.439 $\pm$ 0.074 & 5.609 $\pm$ 0.008 & 7.159 $\pm$ 0.008 & \textbf{0.8782 $\pm$ 0.0013} & 1.2034 $\pm$ 0.0038 \\
# BSK + KAZ & 3.198 $\pm$ 0.126 & 3.713 $\pm$ 0.134 & 5.587 $\pm$ 0.014 & 7.168 $\pm$ 0.033 & 0.8822 $\pm$ 0.0020 & 1.2099 $\pm$ 0.0078 \\
# BSK + SFT & 3.020 $\pm$ 0.124 & 3.517 $\pm$ 0.156 & 5.592 $\pm$ 0.012 & 7.158 $\pm$ 0.015 & 0.8811 $\pm$ 0.0021 & 1.2110 $\pm$ 0.0099 \\
# BSK + SPP & 3.144 $\pm$ 0.135 & 3.562 $\pm$ 0.123 & 5.587 $\pm$ 0.003 & 7.143 $\pm$ 0.003 & 0.8786 $\pm$ 0.0003 & 1.2034 $\pm$ 0.0003 \\
# KAZ + SFT & 3.049 $\pm$ 0.133 & 3.529 $\pm$ 0.209 & 5.576 $\pm$ 0.007 & 7.150 $\pm$ 0.010 & 0.8799 $\pm$ 0.0010 & 1.2052 $\pm$ 0.0023 \\
# KAZ + SPP & 3.024 $\pm$ 0.128 & 3.582 $\pm$ 0.572 & 5.588 $\pm$ 0.032 & 7.161 $\pm$ 0.089 & 0.8790 $\pm$ 0.0009 & 1.2038 $\pm$ 0.0018 \\
# ORB + AKZ & 3.235 $\pm$ 0.171 & 3.751 $\pm$ 0.190 & 5.643 $\pm$ 0.019 & 7.209 $\pm$ 0.043 & 0.8793 $\pm$ 0.0013 & 1.2039 $\pm$ 0.0023 \\
# ORB + BSK & 3.374 $\pm$ 0.187 & 3.830 $\pm$ 0.191 & 5.636 $\pm$ 0.021 & 7.188 $\pm$ 0.022 & 0.8794 $\pm$ 0.0012 & 1.2050 $\pm$ 0.0044 \\
# ORB + KAZ & 3.332 $\pm$ 0.182 & 3.907 $\pm$ 0.336 & 5.635 $\pm$ 0.033 & 7.191 $\pm$ 0.051 & 0.8793 $\pm$ 0.0011 & 1.2044 $\pm$ 0.0021 \\
# ORB + SFT & 3.133 $\pm$ 0.516 & 4.038 $\pm$ 2.376 & 5.630 $\pm$ 0.036 & 7.214 $\pm$ 0.160 & 0.8789 $\pm$ 0.0013 & 1.2050 $\pm$ 0.0039 \\
# ORB + SPP & 3.111 $\pm$ 0.162 & 3.587 $\pm$ 0.148 & 5.644 $\pm$ 0.020 & 7.193 $\pm$ 0.020 & 0.8791 $\pm$ 0.0005 & 1.2036 $\pm$ 0.0006 \\
# SFT + SPP & 8.257 $\pm$ 11.157 & 10.765 $\pm$ 12.418 & 5.685 $\pm$ 0.239 & 8.812 $\pm$ 4.144 & 0.9360 $\pm$ 0.0622 & 2.2172 $\pm$ 1.0120 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 100.0
UNIT_LABEL = "cm"

latex = make_ape_rpe_rper_table("mh05",prec=3, prec_r=4)
print(latex)

with open("./ResultFigs/ape_rpe_table_mh05.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on mh05 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:mh05_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (cm)}}
# & \multicolumn{2}{c}{\textbf{RPEt (cm/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 15.507 $\pm$ 3.696 & 18.659 $\pm$ 5.298 & 5.511 $\pm$ 0.499 & 9.719 $\pm$ 8.025 & 0.6117 $\pm$ 0.0264 & 0.9710 $\pm$ 0.2931 \\
# BSK & 7.646 $\pm$ 4.448 & 8.438 $\pm$ 4.756 & 5.171 $\pm$ 0.068 & 6.440 $\pm$ 0.109 & 0.6010 $\pm$ 0.0012 & 0.8699 $\pm$ 0.0033 \\
# KAZ & 49.189 $\pm$ 96.810 & 57.091 $\pm$ 111.239 & 5.434 $\pm$ 0.881 & 8.900 $\pm$ 6.898 & 0.6130 $\pm$ 0.0296 & 0.9828 $\pm$ 0.3349 \\
# ORB & 7.415 $\pm$ 2.357 & 8.214 $\pm$ 2.449 & 5.126 $\pm$ 0.081 & 6.390 $\pm$ 0.143 & 0.6008 $\pm$ 0.0033 & 0.8734 $\pm$ 0.0019 \\
# SFT & 9.035 $\pm$ 3.154 & 10.580 $\pm$ 3.814 & 5.516 $\pm$ 0.418 & 20.056 $\pm$ 18.533 & 0.6243 $\pm$ 0.0315 & 1.0964 $\pm$ 0.2683 \\
# SPP & 5.680 $\pm$ 0.984 & 6.474 $\pm$ 1.004 & 5.222 $\pm$ 0.019 & 6.410 $\pm$ 0.011 & \textbf{0.5868 $\pm$ 0.0006} & \textbf{0.8655 $\pm$ 0.0005} \\
# AKZ + BSK & 79.013 $\pm$ 122.513 & 95.573 $\pm$ 139.978 & 5.767 $\pm$ 1.080 & 13.534 $\pm$ 11.055 & 0.7588 $\pm$ 0.1800 & 2.6271 $\pm$ 2.0894 \\
# AKZ + KAZ & 16.407 $\pm$ 11.852 & 18.629 $\pm$ 13.921 & 5.822 $\pm$ 0.033 & 6.876 $\pm$ 0.073 & 0.6204 $\pm$ 0.0010 & 0.8971 $\pm$ 0.0043 \\
# AKZ + SFT & 82.492 $\pm$ 100.091 & 104.813 $\pm$ 124.432 & 5.987 $\pm$ 1.438 & 13.975 $\pm$ 10.729 & 0.6580 $\pm$ 0.0564 & 1.1717 $\pm$ 0.3309 \\
# AKZ + SPP & 3.693 $\pm$ 0.550 & 4.206 $\pm$ 0.598 & 5.037 $\pm$ 0.008 & \textbf{6.280 $\pm$ 0.010} & 0.5940 $\pm$ 0.0004 & 0.8670 $\pm$ 0.0010 \\
# BSK + KAZ & 8.711 $\pm$ 14.612 & 9.512 $\pm$ 15.718 & 5.709 $\pm$ 0.020 & 6.753 $\pm$ 0.026 & 0.6310 $\pm$ 0.0012 & 0.9066 $\pm$ 0.0036 \\
# BSK + SFT & 61.946 $\pm$ 71.206 & 69.143 $\pm$ 77.826 & 5.493 $\pm$ 0.565 & 9.232 $\pm$ 4.056 & 0.6419 $\pm$ 0.0526 & 1.0660 $\pm$ 0.2574 \\
# BSK + SPP & \textbf{3.607 $\pm$ 0.106} & \textbf{4.103 $\pm$ 0.111} & 5.036 $\pm$ 0.009 & 6.285 $\pm$ 0.022 & 0.5945 $\pm$ 0.0004 & 0.8678 $\pm$ 0.0005 \\
# KAZ + SFT & 13.840 $\pm$ 6.849 & 15.184 $\pm$ 7.301 & \textbf{5.011 $\pm$ 0.029} & 6.310 $\pm$ 0.108 & 0.5974 $\pm$ 0.0016 & 0.8711 $\pm$ 0.0042 \\
# KAZ + SPP & 7.228 $\pm$ 2.716 & 8.294 $\pm$ 2.896 & 5.280 $\pm$ 0.120 & 6.563 $\pm$ 0.378 & 0.6014 $\pm$ 0.0048 & 0.8726 $\pm$ 0.0079 \\
# ORB + AKZ & 17.382 $\pm$ 25.179 & 20.274 $\pm$ 29.863 & 5.093 $\pm$ 0.097 & 6.362 $\pm$ 0.169 & 0.5998 $\pm$ 0.0052 & 0.8717 $\pm$ 0.0056 \\
# ORB + BSK & 6.512 $\pm$ 1.995 & 7.367 $\pm$ 2.264 & 5.109 $\pm$ 0.044 & 6.367 $\pm$ 0.117 & 0.5997 $\pm$ 0.0010 & 0.8705 $\pm$ 0.0020 \\
# ORB + KAZ & 8.405 $\pm$ 7.667 & 9.346 $\pm$ 8.757 & 5.114 $\pm$ 0.052 & 6.357 $\pm$ 0.072 & 0.5910 $\pm$ 0.0068 & 0.8676 $\pm$ 0.0029 \\
# ORB + SFT & 99.496 $\pm$ 54.327 & 111.241 $\pm$ 59.937 & 6.003 $\pm$ 0.593 & 11.768 $\pm$ 3.695 & 0.6824 $\pm$ 0.0554 & 1.1981 $\pm$ 0.2716 \\
# ORB + SPP & 5.698 $\pm$ 1.699 & 6.446 $\pm$ 1.952 & 5.109 $\pm$ 0.082 & 6.362 $\pm$ 0.131 & 0.5972 $\pm$ 0.0049 & 0.8687 $\pm$ 0.0025 \\
# SFT + SPP & 15.058 $\pm$ 13.183 & 23.003 $\pm$ 38.632 & 5.247 $\pm$ 0.543 & 12.353 $\pm$ 25.984 & 0.5995 $\pm$ 0.0137 & 0.9812 $\pm$ 0.4942 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 1.0
UNIT_LABEL = "m"

latex = make_ape_rpe_rper_table("kt00",prec=3, prec_r=4)
print(latex)

with open("./ResultFigs/ape_rpe_table_kt00.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on kt00 sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:kt00_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (m)}}
# & \multicolumn{2}{c}{\textbf{RPEt (m/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 5.053 $\pm$ 1.425 & 5.858 $\pm$ 1.677 & 0.164 $\pm$ 0.019 & 0.412 $\pm$ 0.367 & 0.0623 $\pm$ 0.0041 & 0.1340 $\pm$ 0.0582 \\
# BSK & 16.543 $\pm$ 13.319 & 20.705 $\pm$ 17.102 & 0.252 $\pm$ 0.141 & 1.289 $\pm$ 0.390 & 0.1272 $\pm$ 0.0479 & 0.6058 $\pm$ 0.5290 \\
# KAZ & 5.179 $\pm$ 2.061 & 5.978 $\pm$ 2.498 & 0.238 $\pm$ 0.060 & 0.503 $\pm$ 0.167 & 0.1223 $\pm$ 0.0520 & 0.7272 $\pm$ 0.5386 \\
# ORB & 5.697 $\pm$ 2.086 & 6.550 $\pm$ 2.290 & \textbf{0.133 $\pm$ 0.013} & \textbf{0.228 $\pm$ 0.046} & 0.0666 $\pm$ 0.0019 & 0.1239 $\pm$ 0.0097 \\
# SFT & 8.551 $\pm$ 0.835 & 9.596 $\pm$ 0.995 & 0.213 $\pm$ 0.012 & 0.589 $\pm$ 0.109 & \textbf{0.0551 $\pm$ 0.0034} & \textbf{0.1128 $\pm$ 0.0106} \\
# SPP & 4.501 $\pm$ 0.783 & 8.042 $\pm$ 1.416 & 0.832 $\pm$ 0.168 & 5.832 $\pm$ 1.275 & 0.1459 $\pm$ 0.0428 & 0.9227 $\pm$ 0.5523 \\
# AKZ + BSK & 32.299 $\pm$ 23.254 & 42.261 $\pm$ 29.810 & 1.074 $\pm$ 2.396 & 6.648 $\pm$ 9.580 & 0.4736 $\pm$ 0.8592 & 3.8595 $\pm$ 3.0388 \\
# AKZ + KAZ & 4.942 $\pm$ 1.188 & 5.763 $\pm$ 1.785 & 0.238 $\pm$ 0.020 & 0.377 $\pm$ 0.029 & 0.0612 $\pm$ 0.0006 & 0.1164 $\pm$ 0.0008 \\
# AKZ + SFT & 9.552 $\pm$ 4.243 & 11.249 $\pm$ 5.467 & 0.372 $\pm$ 0.079 & 0.872 $\pm$ 0.455 & 0.0728 $\pm$ 0.0089 & 0.2149 $\pm$ 0.2171 \\
# AKZ + SPP & 6.894 $\pm$ 1.702 & 7.999 $\pm$ 1.880 & 0.443 $\pm$ 0.119 & 1.184 $\pm$ 0.852 & 0.0964 $\pm$ 0.0152 & 0.1911 $\pm$ 0.0698 \\
# BSK + KAZ & 5.234 $\pm$ 1.123 & 6.139 $\pm$ 1.414 & 0.193 $\pm$ 0.017 & 0.299 $\pm$ 0.022 & 0.0669 $\pm$ 0.0017 & 0.1242 $\pm$ 0.0052 \\
# BSK + SFT & 6.872 $\pm$ 2.927 & 8.008 $\pm$ 3.342 & 0.275 $\pm$ 0.023 & 0.472 $\pm$ 0.136 & 0.0760 $\pm$ 0.0107 & 0.1973 $\pm$ 0.0818 \\
# BSK + SPP & 4.213 $\pm$ 0.637 & 4.703 $\pm$ 0.769 & 0.314 $\pm$ 0.018 & 0.573 $\pm$ 0.028 & 0.0666 $\pm$ 0.0011 & 0.1243 $\pm$ 0.0036 \\
# KAZ + SFT & 5.100 $\pm$ 0.844 & 5.802 $\pm$ 1.032 & 0.247 $\pm$ 0.025 & 0.377 $\pm$ 0.028 & 0.0570 $\pm$ 0.0011 & 0.1142 $\pm$ 0.0020 \\
# KAZ + SPP & \textbf{3.892 $\pm$ 0.396} & \textbf{4.291 $\pm$ 0.440} & 0.336 $\pm$ 0.016 & 0.574 $\pm$ 0.034 & 0.0604 $\pm$ 0.0008 & 0.1164 $\pm$ 0.0014 \\
# ORB + AKZ & 9.329 $\pm$ 2.841 & 10.548 $\pm$ 3.187 & 0.238 $\pm$ 0.057 & 1.004 $\pm$ 1.405 & 0.0768 $\pm$ 0.0093 & 0.2352 $\pm$ 0.3620 \\
# ORB + BSK & 10.952 $\pm$ 1.701 & 12.953 $\pm$ 2.119 & 0.270 $\pm$ 0.041 & 0.772 $\pm$ 0.928 & 0.1042 $\pm$ 0.0180 & 0.3832 $\pm$ 0.2007 \\
# ORB + KAZ & 5.074 $\pm$ 0.534 & 5.856 $\pm$ 0.569 & 0.257 $\pm$ 0.024 & 0.413 $\pm$ 0.039 & 0.0661 $\pm$ 0.0007 & 0.1200 $\pm$ 0.0011 \\
# ORB + SFT & 15.852 $\pm$ 5.963 & 18.166 $\pm$ 6.664 & 0.373 $\pm$ 0.080 & 1.677 $\pm$ 1.742 & 0.1093 $\pm$ 0.0230 & 0.6258 $\pm$ 0.6431 \\
# ORB + SPP & 6.565 $\pm$ 1.918 & 7.707 $\pm$ 2.768 & 0.462 $\pm$ 0.112 & 1.003 $\pm$ 0.226 & 0.0966 $\pm$ 0.0106 & 0.1914 $\pm$ 0.0917 \\
# SFT + SPP & 19.717 $\pm$ 9.510 & 24.116 $\pm$ 12.162 & 0.389 $\pm$ 0.349 & 3.940 $\pm$ 2.425 & 0.1231 $\pm$ 0.0592 & 0.9996 $\pm$ 0.9635 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
SCALE = 1.0
UNIT_LABEL = "m"

latex = make_ape_rpe_rper_table("oxf",prec=3, prec_r=4)
print(latex)

with open("./ResultFigs/ape_rpe_table_oxf.tex", "w", encoding="utf-8") as f:
    f.write(latex)
# Out:
# \begin{table}[hbp]
# \centering
# \caption{APE/RPE(trans/rot) on oxf sequence of 20 runs for all feature combinations}
# \scriptsize
# \label{tab:oxf_ape_rpe}\
# \setlength{\tabcolsep}{3pt}
# \begin{tabular}{lcccccc}
# \toprule
# \textbf{Extractor(s)}
# & \multicolumn{2}{c}{\textbf{APE (m)}}
# & \multicolumn{2}{c}{\textbf{RPEt (m/f)}}
# & \multicolumn{2}{c}{\textbf{RPEr (deg/f)}} \\
# \cmidrule(lr){2-3} \cmidrule(lr){4-5} \cmidrule(lr){6-7}
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$
# & Mean $\downarrow$ & RMSE $\downarrow$ \\
# \midrule
# AKZ & 2.242 $\pm$ 1.342 & 2.520 $\pm$ 1.447 & 0.495 $\pm$ 0.002 & 0.524 $\pm$ 0.002 & 0.0087 $\pm$ 0.0001 & 0.0177 $\pm$ 0.0001 \\
# BSK & 92.732 $\pm$ 72.040 & 106.509 $\pm$ 80.114 & 0.508 $\pm$ 0.101 & 0.565 $\pm$ 0.138 & 0.0095 $\pm$ 0.0007 & 0.0183 $\pm$ 0.0013 \\
# KAZ & 110.311 $\pm$ 100.446 & 124.330 $\pm$ 111.056 & 0.558 $\pm$ 0.141 & 0.637 $\pm$ 0.198 & \textbf{0.0082 $\pm$ 0.0005} & \textbf{0.0168 $\pm$ 0.0012} \\
# ORB & 1.778 $\pm$ 0.449 & 1.920 $\pm$ 0.448 & \textbf{0.481 $\pm$ 0.067} & \textbf{0.515 $\pm$ 0.047} & 0.0086 $\pm$ 0.0004 & 0.0177 $\pm$ 0.0003 \\
# SFT & 3.085 $\pm$ 0.422 & 3.349 $\pm$ 0.480 & 0.497 $\pm$ 0.000 & 0.526 $\pm$ 0.000 & 0.0086 $\pm$ 0.0001 & 0.0177 $\pm$ 0.0001 \\
# SPP & 1.556 $\pm$ 0.197 & 1.695 $\pm$ 0.194 & 0.505 $\pm$ 0.041 & 0.533 $\pm$ 0.040 & 0.0086 $\pm$ 0.0004 & 0.0177 $\pm$ 0.0003 \\
# AKZ + BSK & 37.452 $\pm$ 25.049 & 43.089 $\pm$ 28.446 & 0.494 $\pm$ 0.155 & 0.958 $\pm$ 0.903 & 0.0113 $\pm$ 0.0026 & 0.0482 $\pm$ 0.0350 \\
# AKZ + KAZ & 59.144 $\pm$ 76.726 & 66.623 $\pm$ 85.872 & 0.513 $\pm$ 0.080 & 0.560 $\pm$ 0.100 & 0.0085 $\pm$ 0.0004 & 0.0173 $\pm$ 0.0013 \\
# AKZ + SFT & 5.006 $\pm$ 13.408 & 5.619 $\pm$ 15.583 & 0.500 $\pm$ 0.046 & 0.529 $\pm$ 0.044 & 0.0086 $\pm$ 0.0006 & 0.0177 $\pm$ 0.0006 \\
# AKZ + SPP & 12.590 $\pm$ 30.078 & 15.007 $\pm$ 36.169 & 0.516 $\pm$ 0.068 & 0.562 $\pm$ 0.095 & 0.0086 $\pm$ 0.0003 & 0.0177 $\pm$ 0.0004 \\
# BSK + KAZ & 55.305 $\pm$ 55.108 & 64.853 $\pm$ 63.297 & 0.542 $\pm$ 0.162 & 0.693 $\pm$ 0.451 & 0.0086 $\pm$ 0.0004 & 0.0180 $\pm$ 0.0008 \\
# BSK + SFT & 56.223 $\pm$ 64.797 & 65.310 $\pm$ 73.536 & 0.504 $\pm$ 0.065 & 0.561 $\pm$ 0.073 & 0.0088 $\pm$ 0.0004 & 0.0178 $\pm$ 0.0011 \\
# BSK + SPP & 34.827 $\pm$ 53.094 & 39.610 $\pm$ 60.327 & 0.508 $\pm$ 0.055 & 0.554 $\pm$ 0.063 & 0.0087 $\pm$ 0.0005 & 0.0177 $\pm$ 0.0005 \\
# KAZ + SFT & 66.274 $\pm$ 81.690 & 74.030 $\pm$ 90.204 & 0.562 $\pm$ 0.113 & 0.679 $\pm$ 0.291 & 0.0086 $\pm$ 0.0005 & 0.0173 $\pm$ 0.0009 \\
# KAZ + SPP & 56.423 $\pm$ 59.744 & 63.630 $\pm$ 67.112 & 0.507 $\pm$ 0.052 & 0.567 $\pm$ 0.090 & 0.0087 $\pm$ 0.0008 & 0.0180 $\pm$ 0.0009 \\
# ORB + AKZ & 1.956 $\pm$ 0.425 & 2.108 $\pm$ 0.441 & 0.496 $\pm$ 0.000 & 0.525 $\pm$ 0.001 & 0.0086 $\pm$ 0.0000 & 0.0177 $\pm$ 0.0000 \\
# ORB + BSK & 36.479 $\pm$ 38.508 & 42.590 $\pm$ 45.233 & 0.502 $\pm$ 0.062 & 0.563 $\pm$ 0.077 & 0.0089 $\pm$ 0.0006 & 0.0180 $\pm$ 0.0008 \\
# ORB + KAZ & 23.313 $\pm$ 59.405 & 25.826 $\pm$ 65.171 & 0.512 $\pm$ 0.059 & 0.552 $\pm$ 0.083 & 0.0085 $\pm$ 0.0001 & 0.0175 $\pm$ 0.0001 \\
# ORB + SFT & 19.893 $\pm$ 23.132 & 22.087 $\pm$ 25.843 & 0.487 $\pm$ 0.049 & 0.524 $\pm$ 0.043 & 0.0088 $\pm$ 0.0001 & 0.0178 $\pm$ 0.0001 \\
# ORB + SPP & \textbf{1.417 $\pm$ 0.252} & \textbf{1.554 $\pm$ 0.261} & 0.494 $\pm$ 0.004 & 0.523 $\pm$ 0.004 & 0.0087 $\pm$ 0.0001 & 0.0178 $\pm$ 0.0003 \\
# SFT + SPP & 7.959 $\pm$ 12.661 & 9.176 $\pm$ 15.154 & 0.509 $\pm$ 0.072 & 0.540 $\pm$ 0.078 & 0.0086 $\pm$ 0.0011 & 0.0194 $\pm$ 0.0068 \\
# \bottomrule
# \end{tabular}
# \end{table}
